# %%
import kagglehub
from pathlib import Path

DATA_DIR = Path("../data/heartbeat")

# Download latest version
path = kagglehub.dataset_download("shayanfazeli/heartbeat", output_dir=str(DATA_DIR))

print("Path to dataset files: ", path)
# Out:
# ...
# 100%|██████████| 98.8M/98.8M [00:14<00:00, 6.93MB/s]
# Extracting files...
# Path to dataset files:  ../data/heartbeat
